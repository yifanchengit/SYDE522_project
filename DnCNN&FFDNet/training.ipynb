# %% [markdown]
# #Load data/code and save training results

# %%
# !cp -r /content/drive/MyDrive/SYDE522/Project /content

# %%
# !mv -f /content/Project /content/drive/MyDrive/SYDE522

# %% [markdown]
# #1. DnCNN

# %% [markdown]
# 1.1 DnCNN - gaussian_noise_level 15

# %%
# !python /content/drive/MyDrive/SYDE522/Project/Code/KAIR-master/main_train_dncnn.py -opt /content/drive/MyDrive/SYDE522/Project/Data/trainingsettings/train_dncnn_sigma15.json

# %% [markdown]
# 1.2 DnCNN - gaussian_noise_level 25

# %%
# !python /content/drive/MyDrive/SYDE522/Project/Code/KAIR-master/main_train_dncnn.py -opt /content/drive/MyDrive/SYDE522/Project/Data/trainingsettings/train_dncnn_sigma25.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# number of GPUs is: 1
# LogHandlers setup!
# 22-04-25 17:14:54.646 :   task: dncnn25
#   model: plain
#   gpu_ids: [0]
#   scale: 1
#   n_channels: 1
#   merge_bn: True
#   merge_bn_startpoint: 10000
#   path:[
#     root: /content/drive/MyDrive/SYDE522/Project/output/dncnn25
#     pretrained_netG: None
#     task: /content/drive/MyDrive/SYDE522/Project/output/dncnn25/dncnn25
#     log: /content/drive/MyDrive/SYDE522/Project/output/dncnn25/dncnn25
#     options: /content/drive/MyDrive/SYDE522/Project/output/dncnn25/dncnn25/options
#     models: /content/drive/MyDrive/SYDE522/Project/output/dncnn25/dncnn25/models
#     images: /content/drive/MyDrive/SYDE522/Project/output/dncnn25/dncnn25/images
#   ]
#   datasets:[
#     train:[
#       name: train_dataset
#       dataset_type: dncnn
#       dataroot_H: /content/drive/MyDrive/SYDE522/Project/Data/train
#       dataroot_L: None
#       H_size: 40
#       sigma: 25
#       sigma_test: 25
# ...

# %% [markdown]
# 1.3 DnCNN - gaussian_noise_level 50

# %%
# !python /content/drive/MyDrive/SYDE522/Project/Code/KAIR-master/main_train_dncnn.py -opt /content/drive/MyDrive/SYDE522/Project/Data/trainingsettings/train_dncnn_sigma50.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# number of GPUs is: 1
# LogHandlers setup!
# 22-04-25 05:27:27.460 :   task: dncnn50
#   model: plain
#   gpu_ids: [0]
#   scale: 1
#   n_channels: 1
#   merge_bn: True
#   merge_bn_startpoint: 10000
#   path:[
#     root: /content/drive/MyDrive/SYDE522/Project/output/dncnn50
#     pretrained_netG: None
#     task: /content/drive/MyDrive/SYDE522/Project/output/dncnn50/dncnn50
#     log: /content/drive/MyDrive/SYDE522/Project/output/dncnn50/dncnn50
#     options: /content/drive/MyDrive/SYDE522/Project/output/dncnn50/dncnn50/options
#     models: /content/drive/MyDrive/SYDE522/Project/output/dncnn50/dncnn50/models
#     images: /content/drive/MyDrive/SYDE522/Project/output/dncnn50/dncnn50/images
#   ]
#   datasets:[
#     train:[
#       name: train_dataset
#       dataset_type: dncnn
#       dataroot_H: /content/drive/MyDrive/SYDE522/Project/Data/train
#       dataroot_L: None
#       H_size: 40
#       sigma: 50
#       sigma_test: 50
# ...

# %% [markdown]
# #2. FFDNet

# %% [markdown]
# 2.1 FFDNet - gaussian_noise_level 15

# %%
# !python /content/drive/MyDrive/SYDE522/Project/Code/KAIR-master/main_train_dncnn.py -opt /content/drive/MyDrive/SYDE522/Project/Data/trainingsettings/train_ffdnet_sigma15.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# number of GPUs is: 1
# LogHandlers setup!
# 22-04-23 18:03:17.881 :   task: ffdnet15
#   model: plain2
#   gpu_ids: [0]
#   scale: 1
#   n_channels: 1
#   sigma: [0, 75]
#   sigma_test: 15
#   merge_bn: False
#   merge_bn_startpoint: 400000
#   path:[
#     root: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15
#     pretrained_netG: None
#     task: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet15
#     log: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet15
#     options: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet15/options
#     models: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet15/models
#     images: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet15/images
#   ]
#   datasets:[
#     train:[
#       name: train_dataset
#       dataset_type: ffdnet
#       dataroot_H: /content/drive/MyDrive/SYDE522/Project/Data/train
#       dataroot_L: None
#       H_size: 64
# ...

# %% [markdown]
# 2.2 FFDNet - gaussian_noise_level 25

# %%
# !python /content/drive/MyDrive/SYDE522/Project/Code/KAIR-master/main_train_dncnn.py -opt /content/drive/MyDrive/SYDE522/Project/Data/trainingsettings/train_ffdnet_sigma25.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# number of GPUs is: 1
# LogHandlers setup!
# 22-04-23 22:27:39.880 :   task: ffdnet25
#   model: plain2
#   gpu_ids: [0]
#   scale: 1
#   n_channels: 1
#   sigma: [0, 75]
#   sigma_test: 25
#   merge_bn: False
#   merge_bn_startpoint: 400000
#   path:[
#     root: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15
#     pretrained_netG: None
#     task: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet25
#     log: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet25
#     options: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet25/options
#     models: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet25/models
#     images: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet25/images
#   ]
#   datasets:[
#     train:[
#       name: train_dataset
#       dataset_type: ffdnet
#       dataroot_H: /content/drive/MyDrive/SYDE522/Project/Data/train
#       dataroot_L: None
#       H_size: 64
# ...

# %% [markdown]
# 2.3 FFDNet - gaussian_noise_level 50

# %%
# !python /content/drive/MyDrive/SYDE522/Project/Code/KAIR-master/main_train_dncnn.py -opt /content/drive/MyDrive/SYDE522/Project/Data/trainingsettings/train_ffdnet_sigma50.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# number of GPUs is: 1
# LogHandlers setup!
# 22-04-24 03:46:28.088 :   task: ffdnet50
#   model: plain2
#   gpu_ids: [0]
#   scale: 1
#   n_channels: 1
#   sigma: [0, 75]
#   sigma_test: 50
#   merge_bn: False
#   merge_bn_startpoint: 400000
#   path:[
#     root: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15
#     pretrained_netG: None
#     task: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet50
#     log: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet50
#     options: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet50/options
#     models: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet50/models
#     images: /content/drive/MyDrive/SYDE522/Project/output/ffdnet15/ffdnet50/images
#   ]
#   datasets:[
#     train:[
#       name: train_dataset
#       dataset_type: ffdnet
#       dataroot_H: /content/drive/MyDrive/SYDE522/Project/Data/train
#       dataroot_L: None
#       H_size: 64
# ...
